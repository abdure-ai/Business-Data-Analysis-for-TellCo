# %%
import sys
import os
import pandas as pd
# Add the 'scripts' directory to sys.path
sys.path.append(os.path.abspath("../scripts"))

# %%
from Visual import plot_histogram, plot_boxplot, plot_correlation_heatmap, plot_scatter

# %%
# Load the CSV file
file_path = "..\Data\Tellco.csv"  # Replace with your CSV file path
data = pd.read_csv(file_path)

# %%
# Display the first few rows
data.head()
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# ...

# %%
# from db_utils import connect_to_database, fetch_data, close_connection
# from queries import query_telecom_data

# # Connect to the database using parameters from the .env file
# conn = connect_to_database()

# # Fetch data using the query
# if conn:
#     telecom_data = fetch_data(conn, query_telecom_data)
#     close_connection(conn)

# # Display the first few rows of the data
# if telecom_data is not None:
#     print(telecom_data.head())

# %%
# Identify the top 10 handsets
top_10_handsets = data['Handset Type'].value_counts().head(10)

# Display the results
print("Top 10 Handsets:")
print(top_10_handsets)
# Out:
# Top 10 Handsets:
# Handset Type
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: count, dtype: int64

# %%
# Identify the top 3 manufacturers
top_3_manufacturers = telecom_data['Handset Manufacturer'].value_counts().head(3)

# Display the results
print("Top 3 Handset Manufacturers:")
print(top_3_manufacturers)
# Out:
# Top 3 Handset Manufacturers:
# Handset Manufacturer
# Apple      59565
# Samsung    40839
# Huawei     34423
# Name: count, dtype: int64

# %%
# Get the top 3 manufacturers
top_manufacturer_names = top_3_manufacturers.index

# Loop through each manufacturer and find the top 5 handsets
for manufacturer in top_manufacturer_names:
    top_5_handsets = data[data['Handset Manufacturer'] == manufacturer]['Handset Type'].value_counts().head(5)
    print(f"\nTop 5 Handsets for {manufacturer}:")
    print(top_5_handsets)
# Out:
# Top 5 Handsets for Apple:
# Handset Type
# Apple iPhone 6S (A1688)    9419
# Apple iPhone 6 (A1586)     9023
# Apple iPhone 7 (A1778)     6326
# Apple iPhone Se (A1723)    5187
# Apple iPhone 8 (A1905)     4993
# Name: count, dtype: int64
#
# Top 5 Handsets for Samsung:
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4520
# Samsung Galaxy A5 Sm-A520F      3724
# Samsung Galaxy J5 (Sm-J530)     3696
# Samsung Galaxy J3 (Sm-J330)     3484
# Samsung Galaxy S7 (Sm-G930X)    3199
# Name: count, dtype: int64
#
# Top 5 Handsets for Huawei:
# Handset Type
# Huawei B528S-23A                  19752
# Huawei E5180                       2079
# Huawei P20 Lite Huawei Nova 3E     2021
# Huawei P20                         1480
# Huawei Y6 2018                      997
# Name: count, dtype: int64

# %%
# Define the columns to aggregate per user
applications = ['Social Media DL (Bytes)', 'Social Media UL (Bytes)', 
                'Google DL (Bytes)', 'Google UL (Bytes)', 
                'Email DL (Bytes)', 'Email UL (Bytes)', 
                'Youtube DL (Bytes)', 'Youtube UL (Bytes)', 
                'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 
                'Gaming DL (Bytes)', 'Gaming UL (Bytes)', 
                'Other DL (Bytes)', 'Other UL (Bytes)']

# %%
# # Aggregate user-level data
# user_data = data.groupby('IMSI').agg(
#     num_sessions=('IMSI', 'count'),
#     total_duration=('Dur. (ms)', 'sum'),
#     total_download=('Total DL (Bytes)', 'sum'),
#     total_upload=('Total UL (Bytes)', 'sum'),
#     total_data_volume=('Total DL (Bytes)', 'sum') + ('Total UL (Bytes)', 'sum'),
#     **{f"{app}_DL": (app, 'sum') for app in applications if 'DL' in app},
#     **{f"{app}_UL": (app, 'sum') for app in applications if 'UL' in app}
# ).reset_index()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# Step 1: Descriptive Statistics
print("Descriptive Statistics:")
print(data.describe())

# Step 2: Missing Values and Outliers Treatment
# Check for missing values
print("\nMissing Values:")
print(data.isnull().sum())

# Replace missing values with the mean or appropriate method
data.fillna(data.mean(), inplace=True)  # Replace with mean

# Step 3: Variable Transformations - Segment users by decile based on total session duration
data['Total Duration (ms)'] = data['Dur. (ms)']  # Ensure total duration is properly calculated
data['Decile Class'] = pd.qcut(data['Total Duration (ms)'], 10, labels=False)

# Calculate total data per decile class
data['Total Data'] = data['Total DL (Bytes)'] + data['Total UL (Bytes)']
decile_data = data.groupby('Decile Class').agg(
    total_data_per_decile=('Total Data', 'sum')
).reset_index()

# Visualize total data per decile class
plt.figure(figsize=(10, 6))
sns.barplot(x='Decile Class', y='total_data_per_decile', data=decile_data, palette='viridis')
plt.title('Total Data Usage per Decile Class')
plt.xlabel('Decile Class')
plt.ylabel('Total Data (Bytes)')
plt.show()

# Step 4: Univariate Analysis (e.g., Total DL and UL Data)
# Plot histogram and boxplot for 'Total DL (Bytes)'
plt.figure(figsize=(10, 6))
sns.histplot(data['Total DL (Bytes)'], kde=True, color='skyblue')
plt.title('Histogram of Total Download Data (Bytes)')
plt.xlabel('Total Download Data (Bytes)')
plt.ylabel('Frequency')
plt.show()

# Boxplot for Total DL (Bytes)
plt.figure(figsize=(10, 6))
sns.boxplot(x=data['Total DL (Bytes)'], color='lightgreen')
plt.title('Boxplot of Total Download Data (Bytes)')
plt.xlabel('Total Download Data (Bytes)')
plt.show()

# Step 5: Bivariate Analysis (e.g., Social Media Data and Total Data)
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['Social Media DL (Bytes)'], y=data['Total Data'], color='purple')
plt.title('Scatter Plot: Social Media DL (Bytes) vs Total Data')
plt.xlabel('Social Media Download Data (Bytes)')
plt.ylabel('Total Data (Bytes)')
plt.show()

# Step 6: Correlation Analysis
correlation_matrix = data[[
    'Social Media DL (Bytes)', 'Google DL (Bytes)', 'Email DL (Bytes)', 
    'Youtube DL (Bytes)', 'Netflix DL (Bytes)', 'Gaming DL (Bytes)', 
    'Other DL (Bytes)', 'Total DL (Bytes)', 'Total UL (Bytes)'
]].corr()

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# Step 7: Dimensionality Reduction using PCA
# Select the relevant columns for PCA
pca_data = data[[
    'Social Media DL (Bytes)', 'Google DL (Bytes)', 'Email DL (Bytes)', 
    'Youtube DL (Bytes)', 'Netflix DL (Bytes)', 'Gaming DL (Bytes)', 
    'Other DL (Bytes)', 'Total DL (Bytes)', 'Total UL (Bytes)'
]]

# Perform PCA
pca = PCA(n_components=2)  # Reduce to 2 components for visualization
pca_components = pca.fit_transform(pca_data)

# Plot PCA results
plt.figure(figsize=(10, 6))
plt.scatter(pca_components[:, 0], pca_components[:, 1], alpha=0.7, color='orange')
plt.title('PCA of Data Usage')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# PCA Explained Variance
print("\nExplained Variance Ratio by PCA components:")
print(pca.explained_variance_ratio_)
# Out:
# Descriptive Statistics:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# ...
